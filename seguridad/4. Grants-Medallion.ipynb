-- %% [markdown]
-- ##Grants

-- %%
GRANT SELECT ON TABLE catalog_pry.bronze.customers TO `yadmay7@gmail.com`;

-- %%
GRANT USE CATALOG ON CATALOG catalog_pry TO `yadmay7@gmail.com`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_pry.bronze TO `yadmay7@gmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_pry.bronze TO `Desarrolladores`;
GRANT CREATE ON SCHEMA catalog_pry.bronze TO `Desarrolladores`;

-- %%
GRANT CREATE TABLE ON SCHEMA catalog_pry.bronze TO `yadmay7@gmail.com`;

-- %%
GRANT SELECT ON TABLE catalog_pry.silver.orders_enriched TO `Analistas`;

-- %%
SHOW GRANTS ON TABLE catalog_pry.bronze.customers;

-- %%
SHOW GRANTS ON SCHEMA catalog_pry.bronze;

-- %%
SHOW GRANTS ON CATALOG catalog_dev;

-- %%
REVOKE USE SCHEMA ON SCHEMA catalog_pry.bronze FROM `ahuaccachi28@gmail.com`;

-- %%
SHOW GRANTS ON SCHEMA catalog_pry.bronze;

-- %%
SHOW EXTERNAL LOCATIONS

-- %%
SHOW GRANTS ON EXTERNAL LOCATION `exlt-raw`

-- %%
GRANT READ FILES
ON EXTERNAL LOCATION `exlt-raw`
TO `yadmay7@gmail.com`;

-- %%
GRANT WRITE FILES
ON EXTERNAL LOCATION `exlt-bronze`
TO `yadmay7@gmail.com`;

-- %%
GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `exlt-bronze`
TO `yadmay7@gmail.com`;

-- %%
CREATE GROUP `data_engineers`;

-- %%
ALTER GROUP `data_engineers`
ADD USER `ahuaccachi28@gmail.com`;

-- %%
SHOW USERS;
