-- %%
%python
dbutils.widgets.removeAll()

-- %%
%python
dbutils.widgets.text("nameContainer","unit-catalog")
dbutils.widgets.text("nameStorage","adlsproyectoyr1")
dbutils.widgets.text("catalogo","catalog_pry")

-- %%
%python

nameContainer = dbutils.widgets.get("nameContainer")
nameStorage = dbutils.widgets.get("nameStorage")
catalogo = dbutils.widgets.get("catalogo")

ruta = f"abfss://{nameContainer}@{nameStorage}.dfs.core.windows.net"

-- %% [markdown]
-- ### Eliminacion tablas Bronze

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.bronze.categories; 
DROP TABLE IF EXISTS ${catalogo}.bronze.cities;
DROP TABLE IF EXISTS ${catalogo}.bronze.countries;
DROP TABLE IF EXISTS ${catalogo}.bronze.customers; 
DROP TABLE IF EXISTS ${catalogo}.bronze.employees;
DROP TABLE IF EXISTS ${catalogo}.bronze.products;
DROP TABLE IF EXISTS ${catalogo}.bronze.sales;

-- %%
%python
## REMOVE DATA (Bronze)
dbutils.fs.rm(f"{ruta}/tablas/categories", True)
dbutils.fs.rm(f"{ruta}/tablas/cities", True)
dbutils.fs.rm(f"{ruta}/tablas/countries", True)
dbutils.fs.rm(f"{ruta}/tablas/customers", True)
dbutils.fs.rm(f"{ruta}/tablas/employees", True)
dbutils.fs.rm(f"{ruta}/tablas/products", True)
dbutils.fs.rm(f"{ruta}/tablas/sales", True)

-- %% [markdown]
-- ### Eliminacion tablas Silver

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.silver.orders_enriched;

-- %%
%python
# REMOVE DATA (Silver)
dbutils.fs.rm(f"{ruta}/tablas/orders_enriched", True)

-- %% [markdown]
-- ### Eliminacion tablas Golden

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.golden.sales_summary;

-- %%
%python
# REMOVE DATA (Golden)
dbutils.fs.rm(f"{ruta}/tablas/sales_summary", True)
